# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.feature_selection import VarianceThreshold
from sklearn import preprocessing
from sklearn import cross_validation
from sklearn import linear_model
import warnings

import time
from sklearn.feature_extraction import DictVectorizer
from scipy import sparse
import pickle

warnings.simplefilter("ignore")
warnings.filterwarnings("ignore")
from datetime import datetime

import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.cross_validation import StratifiedKFold
from sklearn.feature_selection import RFECV
from sklearn.datasets import make_classification

# %matplotlib inline
t = time.time()
#elapsed = (time.time() - t)/60

# %%
X=np.load('./mostrecentinput/nxtrain_standard_original0.npy')
X1= np.load('./mostrecentinput/nxtrain_standard_derived0.npy')
X2=pd.read_pickle("./mostrecentinput/time_series_derived_standard_train2.dat")
X3=pd.read_pickle("./mostrecentinput/time_series_original_standard_train2.dat")
X=np.hstack((X,X1,X2,X3))

y=pickle.load(open("./mostrecentinput/ytrain2.dat","rb"))

# %%
clf= linear_model.PassiveAggressiveClassifier(loss='squared_hinge',C=1.0)
selector = RFECV(estimator=clf, step=100, cv=StratifiedKFold(y, 20),
              scoring='roc_auc',verbose=2)

selector1 = selector.fit(X, y)
Xselect=X[:,selector1.support_]

clf = linear_model.PassiveAggressiveClassifier(loss='squared_hinge',C=1.0)
skf = cross_validation.StratifiedKFold(y, n_folds=2) 

for train0, cv0 in skf:
    train, cv = train0, cv0
    break

niter=100
preds=0
ncount=0
for i in range(niter):
    MODEL = clf.fit(Xselect[train,:], y[train])
    pred0=MODEL.predict(Xselect[cv,:])
    preds=preds+pred0
    ncount+=1
        
preds=preds/float(ncount)
AUC1=metrics.roc_auc_score(y[cv], preds)


str1=time.strftime("%b%d%Y%H%M%S", time.localtime())
filename='SDG_Aggressive_'  +  str1 + '_AUC_' + str(AUC1) + '.p'
np.arange(X.shape[1])[selector1.support_].dump(filename)

# Plotting
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (nb of correct classifications)")
plt.plot(range(1, len(selector1.grid_scores_) + 1), selector1.grid_scores_)
plt.show()
print(AUC1)
# Out:
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.476902
# Finished fold with 2 / 17 feature ranks, score=0.519543
# Finished fold with 3 / 17 feature ranks, score=0.646871
# Finished fold with 4 / 17 feature ranks, score=0.581449
# Finished fold with 5 / 17 feature ranks, score=0.641844
# Finished fold with 6 / 17 feature ranks, score=0.648284
# Finished fold with 7 / 17 feature ranks, score=0.578567
# Finished fold with 8 / 17 feature ranks, score=0.603898
# Finished fold with 9 / 17 feature ranks, score=0.630406
# Finished fold with 10 / 17 feature ranks, score=0.659800
# Finished fold with 11 / 17 feature ranks, score=0.651511
# Finished fold with 12 / 17 feature ranks, score=0.609526
# Finished fold with 13 / 17 feature ranks, score=0.620883
# Finished fold with 14 / 17 feature ranks, score=0.640795
# Finished fold with 15 / 17 feature ranks, score=0.627614
# Finished fold with 16 / 17 feature ranks, score=0.653680
# Finished fold with 17 / 17 feature ranks, score=0.672300
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.468751
# Finished fold with 2 / 17 feature ranks, score=0.470107
# Finished fold with 3 / 17 feature ranks, score=0.648847
# Finished fold with 4 / 17 feature ranks, score=0.642990
# Finished fold with 5 / 17 feature ranks, score=0.625081
# Finished fold with 6 / 17 feature ranks, score=0.636393
# Finished fold with 7 / 17 feature ranks, score=0.675006
# Finished fold with 8 / 17 feature ranks, score=0.589872
# Finished fold with 9 / 17 feature ranks, score=0.660559
# Finished fold with 10 / 17 feature ranks, score=0.655938
# Finished fold with 11 / 17 feature ranks, score=0.594694
# Finished fold with 12 / 17 feature ranks, score=0.671266
# Finished fold with 13 / 17 feature ranks, score=0.649250
# Finished fold with 14 / 17 feature ranks, score=0.633673
# Finished fold with 15 / 17 feature ranks, score=0.656480
# Finished fold with 16 / 17 feature ranks, score=0.693152
# Finished fold with 17 / 17 feature ranks, score=0.654134
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.476884
# Finished fold with 2 / 17 feature ranks, score=0.500672
# Finished fold with 3 / 17 feature ranks, score=0.656926
# Finished fold with 4 / 17 feature ranks, score=0.591205
# Finished fold with 5 / 17 feature ranks, score=0.679946
# Finished fold with 6 / 17 feature ranks, score=0.661156
# Finished fold with 7 / 17 feature ranks, score=0.600319
# Finished fold with 8 / 17 feature ranks, score=0.668185
# Finished fold with 9 / 17 feature ranks, score=0.667655
# Finished fold with 10 / 17 feature ranks, score=0.635192
# Finished fold with 11 / 17 feature ranks, score=0.600365
# Finished fold with 12 / 17 feature ranks, score=0.531686
# Finished fold with 13 / 17 feature ranks, score=0.618175
# Finished fold with 14 / 17 feature ranks, score=0.626457
# Finished fold with 15 / 17 feature ranks, score=0.622409
# Finished fold with 16 / 17 feature ranks, score=0.679871
# Finished fold with 17 / 17 feature ranks, score=0.644789
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.470070
# Finished fold with 2 / 17 feature ranks, score=0.532410
# Finished fold with 3 / 17 feature ranks, score=0.494545
# Finished fold with 4 / 17 feature ranks, score=0.563303
# Finished fold with 5 / 17 feature ranks, score=0.663007
# Finished fold with 6 / 17 feature ranks, score=0.681168
# Finished fold with 7 / 17 feature ranks, score=0.627173
# Finished fold with 8 / 17 feature ranks, score=0.663782
# Finished fold with 9 / 17 feature ranks, score=0.583172
# Finished fold with 10 / 17 feature ranks, score=0.671722
# Finished fold with 11 / 17 feature ranks, score=0.636507
# Finished fold with 12 / 17 feature ranks, score=0.641527
# Finished fold with 13 / 17 feature ranks, score=0.675466
# Finished fold with 14 / 17 feature ranks, score=0.673172
# Finished fold with 15 / 17 feature ranks, score=0.639015
# Finished fold with 16 / 17 feature ranks, score=0.659067
# Finished fold with 17 / 17 feature ranks, score=0.654375
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.474442
# Finished fold with 2 / 17 feature ranks, score=0.419331
# Finished fold with 3 / 17 feature ranks, score=0.638904
# Finished fold with 4 / 17 feature ranks, score=0.624534
# Finished fold with 5 / 17 feature ranks, score=0.693117
# Finished fold with 6 / 17 feature ranks, score=0.615677
# Finished fold with 7 / 17 feature ranks, score=0.666490
# Finished fold with 8 / 17 feature ranks, score=0.640467
# Finished fold with 9 / 17 feature ranks, score=0.646230
# Finished fold with 10 / 17 feature ranks, score=0.598223
# Finished fold with 11 / 17 feature ranks, score=0.647984
# Finished fold with 12 / 17 feature ranks, score=0.612713
# Finished fold with 13 / 17 feature ranks, score=0.628241
# Finished fold with 14 / 17 feature ranks, score=0.605834
# Finished fold with 15 / 17 feature ranks, score=0.635936
# Finished fold with 16 / 17 feature ranks, score=0.601942
# Finished fold with 17 / 17 feature ranks, score=0.673169
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.486975
# Finished fold with 2 / 17 feature ranks, score=0.522819
# Finished fold with 3 / 17 feature ranks, score=0.633197
# Finished fold with 4 / 17 feature ranks, score=0.673742
# Finished fold with 5 / 17 feature ranks, score=0.516304
# Finished fold with 6 / 17 feature ranks, score=0.626174
# Finished fold with 7 / 17 feature ranks, score=0.626631
# Finished fold with 8 / 17 feature ranks, score=0.669679
# Finished fold with 9 / 17 feature ranks, score=0.619938
# Finished fold with 10 / 17 feature ranks, score=0.632249
# Finished fold with 11 / 17 feature ranks, score=0.695504
# Finished fold with 12 / 17 feature ranks, score=0.660392
# Finished fold with 13 / 17 feature ranks, score=0.616009
# Finished fold with 14 / 17 feature ranks, score=0.627123
# Finished fold with 15 / 17 feature ranks, score=0.630671
# Finished fold with 16 / 17 feature ranks, score=0.654790
# Finished fold with 17 / 17 feature ranks, score=0.619188
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.518159
# Finished fold with 2 / 17 feature ranks, score=0.522341
# Finished fold with 3 / 17 feature ranks, score=0.509896
# Finished fold with 4 / 17 feature ranks, score=0.649349
# Finished fold with 5 / 17 feature ranks, score=0.639995
# Finished fold with 6 / 17 feature ranks, score=0.664729
# Finished fold with 7 / 17 feature ranks, score=0.601272
# Finished fold with 8 / 17 feature ranks, score=0.597400
# Finished fold with 9 / 17 feature ranks, score=0.630998
# Finished fold with 10 / 17 feature ranks, score=0.642088
# Finished fold with 11 / 17 feature ranks, score=0.637371
# Finished fold with 12 / 17 feature ranks, score=0.681480
# Finished fold with 13 / 17 feature ranks, score=0.637566
# Finished fold with 14 / 17 feature ranks, score=0.677615
# Finished fold with 15 / 17 feature ranks, score=0.670555
# Finished fold with 16 / 17 feature ranks, score=0.669796
# Finished fold with 17 / 17 feature ranks, score=0.699920
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.550569
# Finished fold with 2 / 17 feature ranks, score=0.514475
# Finished fold with 3 / 17 feature ranks, score=0.568372
# Finished fold with 4 / 17 feature ranks, score=0.589632
# Finished fold with 5 / 17 feature ranks, score=0.635507
# Finished fold with 6 / 17 feature ranks, score=0.685449
# Finished fold with 7 / 17 feature ranks, score=0.627656
# Finished fold with 8 / 17 feature ranks, score=0.594937
# Finished fold with 9 / 17 feature ranks, score=0.560538
# Finished fold with 10 / 17 feature ranks, score=0.621437
# Finished fold with 11 / 17 feature ranks, score=0.585819
# Finished fold with 12 / 17 feature ranks, score=0.566509
# Finished fold with 13 / 17 feature ranks, score=0.631449
# Finished fold with 14 / 17 feature ranks, score=0.632644
# Finished fold with 15 / 17 feature ranks, score=0.596142
# Finished fold with 16 / 17 feature ranks, score=0.688890
# Finished fold with 17 / 17 feature ranks, score=0.590104
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.455904
# Finished fold with 2 / 17 feature ranks, score=0.482293
# Finished fold with 3 / 17 feature ranks, score=0.640002
# Finished fold with 4 / 17 feature ranks, score=0.596098
# Finished fold with 5 / 17 feature ranks, score=0.643956
# Finished fold with 6 / 17 feature ranks, score=0.630136
# Finished fold with 7 / 17 feature ranks, score=0.518802
# Finished fold with 8 / 17 feature ranks, score=0.666297
# Finished fold with 9 / 17 feature ranks, score=0.644502
# Finished fold with 10 / 17 feature ranks, score=0.661648
# Finished fold with 11 / 17 feature ranks, score=0.655988
# Finished fold with 12 / 17 feature ranks, score=0.662007
# Finished fold with 13 / 17 feature ranks, score=0.617937
# Finished fold with 14 / 17 feature ranks, score=0.680455
# Finished fold with 15 / 17 feature ranks, score=0.683856
# Finished fold with 16 / 17 feature ranks, score=0.639536
# Finished fold with 17 / 17 feature ranks, score=0.646762
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.471133
# Finished fold with 2 / 17 feature ranks, score=0.505786
# Finished fold with 3 / 17 feature ranks, score=0.607966
# Finished fold with 4 / 17 feature ranks, score=0.608171
# Finished fold with 5 / 17 feature ranks, score=0.676325
# Finished fold with 6 / 17 feature ranks, score=0.664597
# Finished fold with 7 / 17 feature ranks, score=0.650867
# Finished fold with 8 / 17 feature ranks, score=0.550447
# Finished fold with 9 / 17 feature ranks, score=0.632659
# Finished fold with 10 / 17 feature ranks, score=0.658061
# Finished fold with 11 / 17 feature ranks, score=0.611598
# Finished fold with 12 / 17 feature ranks, score=0.629902
# Finished fold with 13 / 17 feature ranks, score=0.650715
# Finished fold with 14 / 17 feature ranks, score=0.678918
# Finished fold with 15 / 17 feature ranks, score=0.652597
# Finished fold with 16 / 17 feature ranks, score=0.643407
# Finished fold with 17 / 17 feature ranks, score=0.569587
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.478588
# Finished fold with 2 / 17 feature ranks, score=0.489626
# Finished fold with 3 / 17 feature ranks, score=0.575634
# Finished fold with 4 / 17 feature ranks, score=0.645511
# Finished fold with 5 / 17 feature ranks, score=0.680651
# Finished fold with 6 / 17 feature ranks, score=0.635366
# Finished fold with 7 / 17 feature ranks, score=0.677852
# Finished fold with 8 / 17 feature ranks, score=0.621598
# Finished fold with 9 / 17 feature ranks, score=0.605328
# Finished fold with 10 / 17 feature ranks, score=0.639020
# Finished fold with 11 / 17 feature ranks, score=0.659183
# Finished fold with 12 / 17 feature ranks, score=0.659735
# Finished fold with 13 / 17 feature ranks, score=0.649398
# Finished fold with 14 / 17 feature ranks, score=0.677031
# Finished fold with 15 / 17 feature ranks, score=0.622862
# Finished fold with 16 / 17 feature ranks, score=0.632717
# Finished fold with 17 / 17 feature ranks, score=0.683583
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.483951
# Finished fold with 2 / 17 feature ranks, score=0.507211
# Finished fold with 3 / 17 feature ranks, score=0.621250
# Finished fold with 4 / 17 feature ranks, score=0.625998
# Finished fold with 5 / 17 feature ranks, score=0.617899
# Finished fold with 6 / 17 feature ranks, score=0.655471
# Finished fold with 7 / 17 feature ranks, score=0.583017
# Finished fold with 8 / 17 feature ranks, score=0.621807
# Finished fold with 9 / 17 feature ranks, score=0.583906
# Finished fold with 10 / 17 feature ranks, score=0.605662
# Finished fold with 11 / 17 feature ranks, score=0.639245
# Finished fold with 12 / 17 feature ranks, score=0.660492
# Finished fold with 13 / 17 feature ranks, score=0.642497
# Finished fold with 14 / 17 feature ranks, score=0.654172
# Finished fold with 15 / 17 feature ranks, score=0.619422
# Finished fold with 16 / 17 feature ranks, score=0.666193
# Finished fold with 17 / 17 feature ranks, score=0.665383
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.530037
# Finished fold with 2 / 17 feature ranks, score=0.506806
# Finished fold with 3 / 17 feature ranks, score=0.641514
# Finished fold with 4 / 17 feature ranks, score=0.604597
# Finished fold with 5 / 17 feature ranks, score=0.585069
# Finished fold with 6 / 17 feature ranks, score=0.609226
# Finished fold with 7 / 17 feature ranks, score=0.652070
# Finished fold with 8 / 17 feature ranks, score=0.642558
# Finished fold with 9 / 17 feature ranks, score=0.656017
# Finished fold with 10 / 17 feature ranks, score=0.675440
# Finished fold with 11 / 17 feature ranks, score=0.632068
# Finished fold with 12 / 17 feature ranks, score=0.707762
# Finished fold with 13 / 17 feature ranks, score=0.625844
# Finished fold with 14 / 17 feature ranks, score=0.683178
# Finished fold with 15 / 17 feature ranks, score=0.637371
# Finished fold with 16 / 17 feature ranks, score=0.658348
# Finished fold with 17 / 17 feature ranks, score=0.660038
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.521497
# Finished fold with 2 / 17 feature ranks, score=0.445338
# Finished fold with 3 / 17 feature ranks, score=0.593932
# Finished fold with 4 / 17 feature ranks, score=0.625522
# Finished fold with 5 / 17 feature ranks, score=0.640928
# Finished fold with 6 / 17 feature ranks, score=0.620042
# Finished fold with 7 / 17 feature ranks, score=0.616009
# Finished fold with 8 / 17 feature ranks, score=0.677197
# Finished fold with 9 / 17 feature ranks, score=0.574565
# Finished fold with 10 / 17 feature ranks, score=0.648634
# Finished fold with 11 / 17 feature ranks, score=0.700327
# Finished fold with 12 / 17 feature ranks, score=0.636765
# Finished fold with 13 / 17 feature ranks, score=0.610993
# Finished fold with 14 / 17 feature ranks, score=0.584768
# Finished fold with 15 / 17 feature ranks, score=0.638139
# Finished fold with 16 / 17 feature ranks, score=0.688654
# Finished fold with 17 / 17 feature ranks, score=0.636136
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.539119
# Finished fold with 2 / 17 feature ranks, score=0.537275
# Finished fold with 3 / 17 feature ranks, score=0.558392
# Finished fold with 4 / 17 feature ranks, score=0.626653
# Finished fold with 5 / 17 feature ranks, score=0.642842
# Finished fold with 6 / 17 feature ranks, score=0.667853
# Finished fold with 7 / 17 feature ranks, score=0.602947
# Finished fold with 8 / 17 feature ranks, score=0.600760
# Finished fold with 9 / 17 feature ranks, score=0.629562
# Finished fold with 10 / 17 feature ranks, score=0.604512
# Finished fold with 11 / 17 feature ranks, score=0.621556
# Finished fold with 12 / 17 feature ranks, score=0.651853
# Finished fold with 13 / 17 feature ranks, score=0.554767
# Finished fold with 14 / 17 feature ranks, score=0.615555
# Finished fold with 15 / 17 feature ranks, score=0.655739
# Finished fold with 16 / 17 feature ranks, score=0.628824
# Finished fold with 17 / 17 feature ranks, score=0.619794
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.451465
# Finished fold with 2 / 17 feature ranks, score=0.478987
# Finished fold with 3 / 17 feature ranks, score=0.607318
# Finished fold with 4 / 17 feature ranks, score=0.517251
# Finished fold with 5 / 17 feature ranks, score=0.552047
# Finished fold with 6 / 17 feature ranks, score=0.678301
# Finished fold with 7 / 17 feature ranks, score=0.636263
# Finished fold with 8 / 17 feature ranks, score=0.617535
# Finished fold with 9 / 17 feature ranks, score=0.678355
# Finished fold with 10 / 17 feature ranks, score=0.660887
# Finished fold with 11 / 17 feature ranks, score=0.651154
# Finished fold with 12 / 17 feature ranks, score=0.644799
# Finished fold with 13 / 17 feature ranks, score=0.672350
# Finished fold with 14 / 17 feature ranks, score=0.642207
# Finished fold with 15 / 17 feature ranks, score=0.691352
# Finished fold with 16 / 17 feature ranks, score=0.547135
# Finished fold with 17 / 17 feature ranks, score=0.643268
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.558533
# Finished fold with 2 / 17 feature ranks, score=0.558479
# Finished fold with 3 / 17 feature ranks, score=0.603634
# Finished fold with 4 / 17 feature ranks, score=0.671753
# Finished fold with 5 / 17 feature ranks, score=0.673169
# Finished fold with 6 / 17 feature ranks, score=0.609168
# Finished fold with 7 / 17 feature ranks, score=0.616286
# Finished fold with 8 / 17 feature ranks, score=0.673537
# Finished fold with 9 / 17 feature ranks, score=0.643880
# Finished fold with 10 / 17 feature ranks, score=0.503348
# Finished fold with 11 / 17 feature ranks, score=0.654777
# Finished fold with 12 / 17 feature ranks, score=0.660492
# Finished fold with 13 / 17 feature ranks, score=0.685008
# Finished fold with 14 / 17 feature ranks, score=0.694713
# Finished fold with 15 / 17 feature ranks, score=0.671308
# Finished fold with 16 / 17 feature ranks, score=0.627855
# Finished fold with 17 / 17 feature ranks, score=0.629028
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.466920
# Finished fold with 2 / 17 feature ranks, score=0.573523
# Finished fold with 3 / 17 feature ranks, score=0.562663
# Finished fold with 4 / 17 feature ranks, score=0.648900
# Finished fold with 5 / 17 feature ranks, score=0.665352
# Finished fold with 6 / 17 feature ranks, score=0.669523
# Finished fold with 7 / 17 feature ranks, score=0.590844
# Finished fold with 8 / 17 feature ranks, score=0.655189
# Finished fold with 9 / 17 feature ranks, score=0.678192
# Finished fold with 10 / 17 feature ranks, score=0.519234
# Finished fold with 11 / 17 feature ranks, score=0.683595
# Finished fold with 12 / 17 feature ranks, score=0.624958
# Finished fold with 13 / 17 feature ranks, score=0.642796
# Finished fold with 14 / 17 feature ranks, score=0.619791
# Finished fold with 15 / 17 feature ranks, score=0.662339
# Finished fold with 16 / 17 feature ranks, score=0.709596
# Finished fold with 17 / 17 feature ranks, score=0.617768
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.469423
# Finished fold with 2 / 17 feature ranks, score=0.597587
# Finished fold with 3 / 17 feature ranks, score=0.556022
# Finished fold with 4 / 17 feature ranks, score=0.634695
# Finished fold with 5 / 17 feature ranks, score=0.641935
# Finished fold with 6 / 17 feature ranks, score=0.567390
# Finished fold with 7 / 17 feature ranks, score=0.659395
# Finished fold with 8 / 17 feature ranks, score=0.659782
# Finished fold with 9 / 17 feature ranks, score=0.622679
# Finished fold with 10 / 17 feature ranks, score=0.670951
# Finished fold with 11 / 17 feature ranks, score=0.675777
# Finished fold with 12 / 17 feature ranks, score=0.623062
# Finished fold with 13 / 17 feature ranks, score=0.623843
# Finished fold with 14 / 17 feature ranks, score=0.648683
# Finished fold with 15 / 17 feature ranks, score=0.674408
# Finished fold with 16 / 17 feature ranks, score=0.684250
# Finished fold with 17 / 17 feature ranks, score=0.651664
# Fitting estimator with 1503 features.
# Fitting estimator with 1403 features.
# Fitting estimator with 1303 features.
# Fitting estimator with 1203 features.
# Fitting estimator with 1103 features.
# Fitting estimator with 1003 features.
# Fitting estimator with 903 features.
# Fitting estimator with 803 features.
# Fitting estimator with 703 features.
# Fitting estimator with 603 features.
# Fitting estimator with 503 features.
# Fitting estimator with 403 features.
# Fitting estimator with 303 features.
# Fitting estimator with 203 features.
# Fitting estimator with 103 features.
# Fitting estimator with 3 features.
# Finished fold with 1 / 17 feature ranks, score=0.466290
# Finished fold with 2 / 17 feature ranks, score=0.469104
# Finished fold with 3 / 17 feature ranks, score=0.679117
# Finished fold with 4 / 17 feature ranks, score=0.642151
# Finished fold with 5 / 17 feature ranks, score=0.652489
# Finished fold with 6 / 17 feature ranks, score=0.673291
# Finished fold with 7 / 17 feature ranks, score=0.686064
# Finished fold with 8 / 17 feature ranks, score=0.642950
# Finished fold with 9 / 17 feature ranks, score=0.694586
# Finished fold with 10 / 17 feature ranks, score=0.660978
# Finished fold with 11 / 17 feature ranks, score=0.649690
# Finished fold with 12 / 17 feature ranks, score=0.696257
# Finished fold with 13 / 17 feature ranks, score=0.675612
# Finished fold with 14 / 17 feature ranks, score=0.623203
# Finished fold with 15 / 17 feature ranks, score=0.697387
# Finished fold with 16 / 17 feature ranks, score=0.637503
# Finished fold with 17 / 17 feature ranks, score=0.693737
# 0.759287428967

# %%
niter=1000
preds=0
ncount=0
for i in range(niter):
    MODEL = clf.fit(Xselect[train,:], y[train])
    pred0=MODEL.predict(Xselect[cv,:])
    preds=preds+pred0
    ncount+=1
        
preds=preds/float(ncount)
AUC1=metrics.roc_auc_score(y[cv], preds)


str1=time.strftime("%b%d%Y%H%M%S", time.localtime())
filename='SDG_Aggressive_'  +  str1 + '_AUC_' + str(AUC1) + '.p'
np.arange(X.shape[1])[selector1.support_].dump(filename)

print(AUC1)
# Out:
# 0.76527875797
